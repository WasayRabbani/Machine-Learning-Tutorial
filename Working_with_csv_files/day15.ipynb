# %%
import pandas as pd

# %% [markdown]
# ## 1. Sep Parameter

# %%
pd.read_csv('random_data.tsv',sep='\t')
# Out:
#     Column_1  Column_2  Column_3  Column_4  Column_5
# 0         29       100        59        37        65
# 1          7        94        98        61         7
# 2         38        83        93        93        19
# 3         52        13        79        52         3
# 4         93         5        87        51        46
# 5         11        63        18         8        25
# 6         72         6        88        62        86
# 7         89        46        39        13        59
# 8         12         2        12        44        14
# 9          6        84        42        15        31
# 10        45        24        21        86        86
# 11        16        10        68        58        79
# 12         1        30        24        56        57
# 13        16        45        69        60        20
# 14        13        75        35        37        27
# 15         7        22        41        65         8
# 16        83        15        20         8        44
# ...

# %% [markdown]
# ## 2. Index_col Parameter

# %%
pd.read_csv('header.csv',index_col='Sequence')
# Out:
#           energy   key  loudness  mode  speechiness  acousticness  \
# Sequence
# 8949      0.6240   7.0    -6.764   0.0       0.0477         0.451
# 29725     0.7030  10.0    -7.951   0.0       0.3060         0.206
# 11561     0.0149   1.0   -27.528   1.0       0.0419         0.992
# 33241     0.7360   3.0    -6.994   0.0       0.0585         0.431
# 666       0.5720   1.0    -7.516   1.0       0.2220         0.145
# ...          ...   ...       ...   ...          ...           ...
# 7386         NaN   NaN       NaN   NaN          NaN           NaN
# 31398        NaN   NaN       NaN   NaN          NaN           NaN
# 24576        NaN   NaN       NaN   NaN          NaN           NaN
# 5756         NaN   NaN       NaN   NaN          NaN           NaN
# 23834        NaN   NaN       NaN   NaN          NaN           NaN
#
#           instrumentalness  liveness  valence    tempo  ...  Unnamed: 21  \
# Sequence                                                ...
# ...

# %% [markdown]
# ## 3. Header

# %%
pd.read_csv('test.csv',header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# ## 4. use_col parameter

# %%
pd.read_csv('header.csv',usecols=['Sequence','energy','key'])
# Out:
#        Sequence  energy   key
# 0          8949  0.6240   7.0
# 1         29725  0.7030  10.0
# 2         11561  0.0149   1.0
# 3         33241  0.7360   3.0
# 4           666  0.5720   1.0
# ...         ...     ...   ...
# 19153      7386     NaN   NaN
# 19154     31398     NaN   NaN
# 19155     24576     NaN   NaN
# 19156      5756     NaN   NaN
# 19157     23834     NaN   NaN
#
# [19158 rows x 3 columns]

# %% [markdown]
# ## 5. Skip Bad Lines/on_bad_lines parameter

# %%
df=pd.read_csv('practice_bad_lines.csv',on_bad_lines='skip')
df.head()
# Out:
#    id    name   age         city               email   salary department  \
# 0   8   Name8  40.0      Houston   name8@example.com  87128.0  Marketing
# 1  21  Name21  24.0  Los Angeles  name21@example.com  75632.0  Marketing
# 2   6   Name6  28.0     New York   name6@example.com  64568.0  Marketing
# 3  27  Name27  29.0      Phoenix  name27@example.com  85363.0         IT
# 4  34     NaN   NaN          NaN                 NaN      NaN        NaN
#
#   joining_date    status
# 0   2021-07-16    Active
# 1   2022-03-21  Inactive
# 2   2021-03-14  Inactive
# 3   2023-01-16    Active
# 4          NaN       NaN

# %% [markdown]
# ## 6. Encoding Parameter

# %%
pd.read_csv('wrongEncoding.csv',on_bad_lines='skip',encoding='ISO-8859-1')
# Out:
#     id     name   age         city               email    salary department  \
# 0    8    Name8  40.0      Houston   name8@example.com   87128.0  Marketing
# 1   21   Name21  24.0  Los Angeles  name21@example.com   75632.0  Marketing
# 2    6    Name6  28.0     New York   name6@example.com   64568.0  Marketing
# 3   27   Name27  29.0      Phoenix  name27@example.com   85363.0         IT
# 4   34      NaN   NaN          NaN                 NaN       NaN        NaN
# 5   13   Name13  42.0  Los Angeles  name13@example.com   98369.0  Marketing
# 6   15   Name15  60.0      Houston  name15@example.com   62427.0  Marketing
# 7   10   Name10  50.0     New York  name10@example.com   54937.0         IT
# 8   26   Name26  30.0      Phoenix  name26@example.com  100203.0         IT
# 9   31  BadRow1  35.0        Miami                 NaN       NaN        NaN
# 10   7    Name7  51.0      Chicago   name7@example.com   50259.0  Marketing
# ...

# %% [markdown]
# ## 7. Changing D-Type of Columns

# %%
pd.read_csv('aug_train.csv',dtype={'target':'int'})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## 8. Changing date time

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ## 9. Loading huge dataset into chunks

# %%
df=pd.read_csv('aug_train.csv',chunksize=7000)
for chunk in df:
    print(chunk.shape)
# Out:
# (7000, 14)
# (7000, 14)
# (5158, 14)

# %% [markdown]
# ## 10. Convertors

# %%
def rename(name):
    if name=='Kolkata Knight Riders':
        return 'KKR'
    else:
        return name

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team2':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...
