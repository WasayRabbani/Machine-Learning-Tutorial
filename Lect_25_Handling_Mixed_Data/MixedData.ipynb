# %% [markdown]
# ### Lecture 24: Handing Mixed Data in a Column

# %% [markdown]
# Steps
# 1. See which column has mixed variables
# 2. Checking total no of categories in a column
# 3. Checking type of Mixed Data (Single,multi,space between them)
# 4. Extracting Numerical Part
# 5. Extracting Categorical Part

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# Importing Data

# %%
df=pd.read_csv('avocado_ripeness_dataset.csv')
df.head()
# Out:
#    firmness    hue  saturation  brightness color_category  sound_db  weight_g  \
# 0      14.5   19.0        40.0        26.0          black      34.0     175.0
# 1      71.7   53.0        69.0        75.0          green      69.0     206.0
# 2      88.5   60.0        94.0        46.0     dark green      79.0     220.0
# 3      93.8  105.0        87.0        41.0     dark green      75.0     299.0
# 4      42.5  303.0        58.0        32.0         purple      63.0     200.0
#
#    size_cm3         ripeness Quality Tag Avocado Num
# 0     261.0             ripe     A10  21      330911
# 1     185.0  pre-conditioned     A40   4      363272
# 2     143.0             hard      B2   7      240276
# 3     140.0             hard      C2   3      315154
# 4     227.0         breaking      D7   2     3101298

# %% [markdown]
# Step 1: Checking which columns have mixed data

# %% [markdown]
# ###### Here Tag & Quality are columns having mixed data

# %% [markdown]
# Step 2: Checking total no of categories in a column

# %%
df['Quality'].unique()
# Out:
# array(['A10', 'A40', 'B2', 'C2', 'D7', 'D2', 'C3', 'A3', 'A4', 'C1', 'B3',
#        nan], dtype=object)

# %% [markdown]
# Step 3: Check type of mixed data (Single/Multi)

# %% [markdown]
# #### Single Type

# %% [markdown]
# Step 4: Extracting Numerical Part

# %%
df['Tag_numerical']=pd.to_numeric(df['Tag'],downcast='integer',errors='coerce')

# %% [markdown]
# Step 5: Extracting Categorical Part

# %%
df['Tag_categorical']=np.where(df['Tag_numerical'].isnull(),df['Tag'],np.nan)

# %%
df.sample(5)
# Out:
#      firmness    hue  saturation  brightness color_category  sound_db  \
# 275       NaN    NaN         NaN         NaN            NaN       NaN
# 186      58.3  272.0        62.0        57.0         purple      58.0
# 342       NaN    NaN         NaN         NaN            NaN       NaN
# 144      56.1  322.0        54.0        39.0         purple      63.0
# 345       NaN    NaN         NaN         NaN            NaN       NaN
#
#      weight_g  size_cm3  ripeness Quality  Tag  Avocado Num  Tag_numerical  \
# 275       NaN       NaN       NaN     NaN  NaN       236853            NaN
# 186     242.0     239.0  breaking      C2    2  S.O./P.P. 2            2.0
# 342       NaN       NaN       NaN     NaN  NaN     CA. 2343            NaN
# 144     196.0     200.0  breaking      D2   78        17475           78.0
# 345       NaN       NaN       NaN     NaN  NaN       348125            NaN
#
#     Tag_categorical
# 275             NaN
# 186             NaN
# 342             NaN
# ...

# %% [markdown]
# #### Multi No Space

# %%
df['Quality'].unique()
# Out:
# array(['A10', 'A40', 'B2', 'C2', 'D7', 'D2', 'C3', 'A3', 'A4', 'C1', 'B3',
#        nan], dtype=object)

# %% [markdown]
# Step 4: Capture Numerical Part

# %%
df['Quality_numerical'] = df['Quality'].str.extract(r'(\d+)')

# %% [markdown]
# Step 5: Capturing Categorical Part

# %%
df['Quality_categorical'] = df['Quality'].str[0]

# %%
df.head()
# Out:
#    firmness    hue  saturation  brightness color_category  sound_db  weight_g  \
# 0      14.5   19.0        40.0        26.0          black      34.0     175.0
# 1      71.7   53.0        69.0        75.0          green      69.0     206.0
# 2      88.5   60.0        94.0        46.0     dark green      79.0     220.0
# 3      93.8  105.0        87.0        41.0     dark green      75.0     299.0
# 4      42.5  303.0        58.0        32.0         purple      63.0     200.0
#
#    size_cm3         ripeness Quality Tag Avocado Num  Tag_numerical  \
# 0     261.0             ripe     A10  21      330911           21.0
# 1     185.0  pre-conditioned     A40   4      363272            4.0
# 2     143.0             hard      B2   7      240276            7.0
# 3     140.0             hard      C2   3      315154            3.0
# 4     227.0         breaking      D7   2     3101298            2.0
#
#   Tag_categorical Quality_numerical Quality_categorical
# ...

# %% [markdown]
# #### Multi with Space

# %%
df['Avocado Num'].unique()
# Out:
# array(['330911', '363272', '240276', '315154', '3101298', '7538',
#        '330972', '248738', '2657', 'A/4 48871', '349220', '694', '21228',
#        '24065', 'W.E.P. 5734', 'SC/PARIS 2167', '233734', '2692',
#        'STON/O2. 3101270', '2696', 'PC 17603', 'C 17368', 'PC 17598',
#        'PC 17597', 'PC 17608', 'A/5. 3337', '113509', '2698', '113054',
#        '2662', 'SC/AH 3085', 'C.A. 31029', 'C.A. 2315', 'W./C. 6607',
#        '13236', '2682', '342712', '315087', '345768', '1601', '349256',
#        '113778', 'SOTON/O.Q. 3101263', '237249', '11753',
#        'STON/O 2. 3101291', 'PC 17594', '370374', '11813', 'C.A. 37671',
#        '13695', 'SC/PARIS 2168', '29105', '19950', 'SC/A.3 2861',
#        '382652', '349230', '348122', '386525', '349232', '237216',
#        '347090', '334914', 'F.C.C. 13534', '330963', '113796', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '113503', '359306',
#        '11770', '248744', '368702', '2678', 'PC 17483', '19924', '349238',
# ...

# %% [markdown]
# Step 4: Capture Numerical Part

# %%
# Getting numerical part as string data type
df['Avocado Num Numerical']=df['Avocado Num'].apply(lambda f:f.split()[-1])

# %%
# Converting string type to numerical type
df['Avocado Num Numerical']=pd.to_numeric(df['Avocado Num Numerical'],errors='coerce',downcast='integer')

# %% [markdown]
# Step 5: Capture Categorical Part

# %%
# Splitting num and cat part
df['Avocado Num Cat']=df['Avocado Num'].apply(lambda f:f.split()[0]) 

# Making cat & num columns
df['Avocado Num Cat']=np.where(df['Avocado Num Cat'].str.isdigit(),np.nan,df['Avocado Num Cat'])

# %%
df.sample(10)
# Out:
#      firmness    hue  saturation  brightness color_category  sound_db  \
# 399       NaN    NaN         NaN         NaN            NaN       NaN
# 327       NaN    NaN         NaN         NaN            NaN       NaN
# 209      86.1  119.0        90.0        40.0     dark green      72.0
# 215      23.4   26.0        48.0        31.0          black      50.0
# 340       NaN    NaN         NaN         NaN            NaN       NaN
# 376       NaN    NaN         NaN         NaN            NaN       NaN
# 179      49.8  303.0        69.0        54.0         purple      63.0
# 114      27.6  295.0        58.0        32.0         purple      55.0
# 32       70.5   79.0        71.0        74.0          green      65.0
# 16       73.6   76.0        89.0        71.0          green      69.0
#
#      weight_g  size_cm3         ripeness Quality  Tag Avocado Num  \
# 399       NaN       NaN              NaN     NaN  NaN       21332
# ...
